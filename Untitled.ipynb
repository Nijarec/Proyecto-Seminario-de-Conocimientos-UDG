# %%
import pandas
import numpy
from sklearn import linear_model
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
archivo='Mall_Customers.csv';
data = pandas.read_csv(archivo)
midataframe = pandas.DataFrame(data)
midataframe
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
midataframe.count()
# Out:
# CustomerID                200
# Gender                    200
# Age                       200
# Annual Income (k$)        200
# Spending Score (1-100)    200
# dtype: int64

# %%
print(midataframe.groupby('Gender').size())
# Out:
# Gender
# Female    112
# Male       88
# dtype: int64

# %%
midataframe.drop(['Gender'],1).hist()
plt.show()

# %%
x=numpy.array(midataframe.drop(['Gender'],1))
y=numpy.array(midataframe['Gender'])
x.shape
# Out:
# (200, 4)

# %%
sb.pairplot(midataframe.dropna(), hue='Gender',size=4,vars=["CustomerID", "Age","Annual Income (k$)","Spending Score (1-100)"],kind='reg')

# %%
model = linear_model.LogisticRegression()
model.fit(x,y)
# Out:
# C:\Users\dabiz\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = model.predict(x)
print(predictions)[0:5]
# Out:
# ['Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Female'
# ...
